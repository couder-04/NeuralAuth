# %%
import pandas as pd
df= pd.read_csv("dataset.csv")

# %%
df
# Out:
#        user_id  account_age_days  kyc_verified  phone_verified  \
# 0            1              1424             1               1
# 1            2               429             1               1
# 2            3               566             1               1
# 3            4              1181             1               1
# 4            5               352             1               1
# ...        ...               ...           ...             ...
# 99995    99996               764             1               1
# 99996    99997               199             1               1
# 99997    99998               461             1               1
# 99998    99999               650             1               1
# 99999   100000              1946             1               1
#
#        email_verified  voice_enrolled  speaker_similarity  liveness_score  \
# 0                   1               1            1.000000        0.975395
# ...
